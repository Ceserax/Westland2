# %%
import numpy as np
from bqplot import pyplot as plt
import bqplot
import pandas as pd

# %%
df = pd.read_csv('/Users/keeskoot/nw_project/westland2/Epexspot_dayAhead2.csv')
df
# Out:
#     Unnamed: 0         day  hours buy_volume sell_volume   volume  price
# 0            0  2021-11-28    1.0    1,866.2     3,332.8  3,332.8  189.0
# 1            1  2021-11-28    2.0    2,019.2     3,400.0  3,400.0  192.0
# 2            2  2021-11-28    3.0    2,392.8     3,600.9  3,600.9  188.0
# 3            3  2021-11-28    4.0    2,372.0     3,727.7  3,727.7  181.0
# 4            4  2021-11-28    5.0    2,387.8     3,795.6  3,795.6  176.0
# 5            5  2021-11-28    6.0    2,525.4     3,806.0  3,806.0  174.0
# 6            6  2021-11-28    7.0    2,430.3     3,811.4  3,811.4  181.0
# 7            7  2021-11-28    8.0    2,461.9     3,878.4  3,878.4  185.0
# 8            8  2021-11-28    9.0    2,328.5     4,185.5  4,185.5  186.0
# 9            9  2021-11-28   10.0    2,250.0     4,515.2  4,515.2  200.0
# 10          10  2021-11-28   11.0    2,292.4     4,937.7  4,937.7  203.0
# 11          11  2021-11-28   12.0    2,138.1     4,897.2  4,897.2  210.0
# ...
